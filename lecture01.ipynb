# %%
a=15
b=4
floordivision=a//b
print(floordivision)
remainder=a%b
print(remainder)
# Out:
# 3
# 3

# %%
pen=3
notebook=2
total_Cost=pen*15+notebook*40
print(total_Cost)
# Out:
# 125

# %%
input_num=int(input("enter a num"))

# %%
#Write a program to calculate the average of 5 numbers entered by the user.
sum=0
for i in range(5):
    num=int(input("enter a number"))
    sum+=num
avg=sum/5
print(avg)
# Out:
# 5.0

# %%
num=int(input("enter a number"))
print(num**2)
print(num**3)
print(num**0.5)
# Out:
# 4
# 8
# 1.4142135623730951

# %%
#Write a program to convert total seconds entered by the user into minutes and seconds (Hint:Use // and %). 
total_seconds=int(input("enter total seconds"))
minutes=total_seconds//60
seconds=total_seconds%60
print(f"{total_seconds} second is equal to {minutes}minute and{seconds}second")
# Out:
# 756 second is equal to 12minute and36second

# %%
#A car travels 120 km in 3 hours. Write a program to calculate its average speed
distance=120
time=3
avg_speed=distance/time
print(avg_speed)
# Out:
# 40.0

# %%
#Write a program that asks the user for two integers and prints whether the first number is a multiple of the second number (using %)
num1=int(input("Enter a number"))
num2=int(input("Enter a number"))
if(num1%num2==0):
    print(f"yes {num1} is a multiple of {num2}")
else:
    print(f"no ")
# Out:
# yes 45 is a multiple of 3

# %%
p=int(input("Enter principal amt"))
r=int(input("enter rate of interest"))
t=int(input("Enter time"))
si=(p*r*t)/100
print(si)
# Out:
# 225.0

# %%
#Write a program that takes two floating-point numbers as input and prints their rounded quotient (using // for floor division). 
num1=float(input("enter number 1"))
num2=float(input("Enter number 2"))
rounded_quotient=num1//num2
print(rounded_quotient)
# Out:
# 1.0
