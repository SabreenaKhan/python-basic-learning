# %%
a=15
b=4
floordivision=a//b
print(floordivision)
remainder=a%b
print(remainder)
# Out:
# 3
# 3

# %%
pen=3
notebook=2
total_Cost=pen*15+notebook*40
print(total_Cost)
# Out:
# 125

# %%
input_num=int(input("enter a num"))
