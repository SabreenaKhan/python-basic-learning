# %% [markdown]
# COMPARISON OPERATORS

# %%
#Write a program to input two numbers and check if they are equal
num1=int(input("Enter a number"))
num2=int(input("enter a number"))
if(num1==num2):
    print("equal")
else:
    print("unequal")
# Out:
# unequal

# %%
#Take two numbers as input and print which one is greater. 
num1=int(input("Enter a number"))
num2=int(input("enter a number"))
if(num1>num2):
    print(f"{num1} is greater")
else:
    print(f"{num2} is greater")
# Out:
# 8 is greater

# %%
#Write a program to input three numbers and print the smallest one using comparison operators. 
num1=int(input("Enter a number"))
num2=int(input("enter a number"))
num3=int(input("enter a number"))
if(num1<=num2)and ( num1<=num3):
    print(f"{num1} is smallest")
elif(num2<=3) and (num2<=num1):
    print(f"{num2} is smallest")
else:
    print(f"{num3} is smallest")
# Out:
# 2 is smallest

# %%
#Ask the user for their exam marks. Print "Pass" if marks are greater than or equal to 40, else print "Fail".
marks=int(input("Ente your marks"))
if(marks>=40):
    print("Pass")
else:
    print("Fail")
# Out:
# Pass

# %%
#Ask the user for their age. Print "Eligible to Vote" if age is 18 or more, otherwise "Not Eligible". 
age=int(input("Enter your age"))
if(age>=18):
    print("Eligible to vote")
else:
    print("Not Eligible")
# Out:
# Eligible to vote

# %%
#Take a number as input and check if it is even (num % 2 == 0) or odd. 
num=int(input("Enter a number"))
if(num%2==0):
    print("even")
else:
    print("odd")
# Out:
# even

# %%
#Write a program to input two words and check if they are the same or different. 
word1=str(input("Enter your word"))
word2=str(input("Enter your word"))
if(word1==word2):
    print("same")
else:
    print("different")
# Out:
# same

# %%
#Take the salaries of two employees. Print "Employee A earns more" if A’s salary is greater, otherwise print "Employee B earns more or equal". 
sal1=int(input("Enter your salary"))
sal2=int(input("Enter your salary"))
if(sal1>sal2):
    print("Employee A earns more than Employee B")
elif(sal1<sal2):
    print("Employee B earns more than Emlpoyee A")
else:
    print("both employee earn same salary")
# Out:
# Employee A earns more than Employee B

# %%
#Take a number as input and check if it lies between 10 and 50 (inclusive). 
num=int(input("Enter a number"))
if(num>=10)and(num<=50):
    print("true")
else:
    print("false")
# Out:
# true

# %%
#leap year check
year=int(input("enter year"))
if((year%4==0) and (year%100!=0))or(year%400==0):
    print("It is a leap year")
else:
    print("Not a leap layer")
# Out:
# Not a leap layer

# %% [markdown]
# LOGICAL OPERATORS

# %%
math_marks=int(input("enter maths marks"))
Science_marks=int(input("Enter science marks"))
if(math_marks>=40)and(Science_marks>=40):
    print("pass")
else:
    print("fail")
# Out:
# pass

# %%
#A customer gets a discount if the purchase amount is more than 1000 or they have a membership card. Check if the customer gets the discount. (or) 
amt=int(input("Enter purchase amount"))
has_membership=input("do you have membership card:(yes/no)")
if(amt>1000)or(has_membership=="yes"):
    print("Gets discount")
else:
    print("no discount")
# Out:
# Gets discount

# %%
num=int(input("enter a number"))
if(num%3!=0):
    print("not divisible by 3")
else:
    print("divisible by 3")
# Out:
# divisible by 3

# %%
#teenager check
age=int(input("enter your age"))
if(age>=13) and(age<=19):
    print("Teenager")
else:
    print("not teenager")
# Out:
# Teenager

# %%
#voting and driving eligibility
age=int(input("enter age"))
if(age>=18):
    print("eligible to vote")
else:
    print("not eligible to vote")
if(age>=18)and(age<=70):
    print("eligible to drive")
else:
    print("not eligible")
# Out:
# eligible to vote
# eligible to drive

# %%
att=int(input("enter your attendance percentage"))
assignment=input("have you submitted your assignment:(yes/no)")
if(att>=75)and(assignment=="yes"):
    print("can sit for exam")
else:
    print("cannot sit for exam")
# Out:
# can sit for exam

# %%
#weekend or holiday
day=input("enter day")
holiday=input("is today holiday:(yes/no)")
if(day=="sunday")or(holiday=="yes"):
    print("relax")
else:
    print("dont relax")
# Out:
# relax

# %%
#multiple of 3 and 5
num=int(input("enter a number"))
if(num%3==0)and(num%5==0):
    print("divisible")
else:
    print("not divisible")
# Out:
# divisible

# %%
#login validation
username=input("enter username")
password=input("enter password")
if(username=="admin")and(password=="1234"):
    print("Login successful")
else:
    print("Login failed")
# Out:
# Login successful

# %% [markdown]
# ASSIGNMENT OPERATOR

# %%
var=10
print (var)
# Out:
# 10

# %%
num=5
num+=5
print(num)
# Out:
# 10

# %%
num=3
num-=3
print(num)
# Out:
# 0

# %%
num=5
num**=3
print(num)
# Out:
# 125
