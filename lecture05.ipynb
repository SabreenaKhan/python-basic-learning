# %% [markdown]
# CONDITIONAL STATEMENTS

# %%
#Write a program to check whether a number is positive, negative, or zero. 
num=int(input("Enter a number"))
if(num>0):
    print("number is positive")
elif(num==0):
    print("number is zero")
else:
    print("number is negative")
# Out:
# number is positive

# %%
#Write a program to check if a number is divisible by 5. 
num=int(input("Enter a number"))
if(num%5==0):
    print("divisible")
else:
    print("not divisible")
# Out:
# divisible

# %%
marks=int(input("Enter your marks"))
if(marks>=90):
    print("A")
elif(marks>=75)and(marks<90):
    print("B")
elif(marks>=50)and(marks<75):
    print("C")
else:
    print("Fail")
# Out:
# A

# %%
# Check whether a given year is a leap year or not.
year=int(input("Enter year"))
if((year%4==0)and(year%100!=0))or(year%400==0):
    print("Leap year")
else:
    print("Not a leap year")
# Out:
# Leap year

# %%
#Write a program to display whether a given number is single-digit, double-digit, or more than two digits. 
num=int(input("Enter a numbe"))
if(num>=0)and(num<=9):
    print("Single digit")
elif(num>=10)and(num<=99):
    print("Double digit")
else:
    print("more than two digits")
# Out:
# more than two digits

# %%
# Take input of a day number (1–7) and print the corresponding weekday using elif. 
num=int(input("Enter a day number"))
if(num==1):
    print("Monday")
elif(num==2):
    print("tuesday")
elif(num==3):
    print("wednesday")
elif(num==4):
    print("Thursday")
elif(num==5):
    print("friday")
elif(num==6):
    print("Saturday")
else:
    print("Sunday")
# Out:
# Thursday

# %%
temp=int(input("enter temperature in celsius"))
if(temp<0):
    print("Freezing")
elif(temp>=0)and(temp<=20):
    print("Cold")
elif(temp>=21)and(temp<=35):
    print("warm")
else:
    print("hot")
# Out:
# hot

# %%
# Check if a number is positive and even, positive and odd, or negative. 
num=int(input("enter a number"))
if(num>=0):
    if(num%2==0):
        print("positive and even")
    else:
        print("positive and odd")
else:
    if(num%2==0):
        print("negative and even")
    else:
        print("negative and odd")
# Out:
# positive and even

# %%
#Write a program to check if three sides form a valid triangle. (Sum of any two sides > third side) 
side1=int(input("enter side of  triangle"))
side2=int(input("enter side of  triangle"))
side3=int(input("enter side of  triangle"))
if((side1+side2)>side3)or((side2 + side3)>side1)or((side1 + side3)>side2):
    print("valid triangle")
else:
    print("invalid triangle")
# Out:
# valid triangle

# %%
# Write a program to check if a character is a vowel, consonant, or not an alphabet. 
char=input("enter your character")
char = char.lower()
if char.isalpha():
    if char in 'aeiou':
        print( "Vowel")
    else:
        print( "Consonant")
else:
    print( "Not an alphabet")
# Out:
# Vowel
